# %%
# %matplotlib notebook
from colicoords import load, save, CellPlot, CellListPlot
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
m_cells = load(os.path.join(data_dir, 'cell_obj', 'm_cells_ph_500_filtered_storm_inner.hdf5'))

# %%
m_names = np.genfromtxt(os.path.join(data_dir, 'matched_names', 'm_cells_ph_500_match_filter.txt'), dtype=str)

# %%
m_index = np.searchsorted(m_cells.name, m_names)
m_sorted = m_cells[m_index]
len(m_sorted)
# Out:
# 6401

# %%
plt.figure()
cp = CellPlot(m_sorted[5152])
cp.imshow('brightfield')
cp.plot_storm(data_name='storm_inner')
cp.plot_outline(color='y')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_dir = r'D:\Projects\CC_paper\figure_6_v3'
ph = 500
cond = 'storm_inner'

# %%
def make_graph(r1, r2, r3, r4, step=1):
    fig = plt.figure(figsize=(8,6))

    h = plt.hist(r1[::1], bins='fd', linewidth=1.5, histtype='step', color=colors[0])
    h = plt.hist(r1[::1], bins='fd', linewidth=0, alpha=0.2, color=colors[0])

    h = plt.hist(r2[::1], bins='fd', linewidth=1.5, linestyle='-', histtype='step', color=colors[1])
    h = plt.hist(r2[::1], bins='fd', linewidth=0, linestyle='-', alpha=0.2, color=colors[1])

    h = plt.hist(r3[::1], bins='fd', linewidth=2, histtype='step', color=colors[2])

    h = plt.hist(r4[::1], bins='fd', linewidth=2, histtype='step', color=colors[3])
    plt.xlim(0.5, 2)
    
    return fig

# %%
def prune(arr):
    arr = arr.flatten()
    arr[np.isinf(arr)] = 10
    return arr[~np.isnan(arr)]

# %%
for ph in [500]:
    for cond in ['storm_inner']:
        r_m_inner = prune(np.load(os.path.join(data_dir, 'r_values', 'r_inner_m_ph_{}_{}.npy'.format(ph, cond))))
        r_m_outer = prune(np.load(os.path.join(data_dir, 'r_values', 'r_outer_m_ph_{}_{}.npy'.format(ph, cond))))
        r_gt_inner = prune(np.load(os.path.join(data_dir, 'r_values', 'r_inner_gt_ph_{}_{}.npy'.format(ph, cond))))
        r_gt_outer = prune(np.load(os.path.join(data_dir, 'r_values', 'r_outer_gt_ph_{}_{}.npy'.format(ph, cond))))
        
        fig = make_graph(r_gt_inner, r_gt_outer, r_m_inner, r_m_outer)
        
        plt.savefig('hist_{}_{}.png'.format(ph, cond), dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e40e73e18c58> in <module>
#       1 for ph in [500]:
#       2     for cond in ['storm_inner']:
# ----> 3         r_m_inner = prune(np.load(os.path.join(data_dir, 'r_values', 'r_inner_m_ph_{}_{}.npy'.format(ph, cond))))
#       4         r_m_outer = prune(np.load(os.path.join(data_dir, 'r_values', 'r_outer_m_ph_{}_{}.npy'.format(ph, cond))))
#       5         r_gt_inner = prune(np.load(os.path.join(data_dir, 'r_values', 'r_inner_gt_ph_{}_{}.npy'.format(ph, cond))))
#
# NameError: name 'np' is not defined

# %%
r_m_inner = prune(np.load(os.path.join(data_dir, 'r_values', 'r_inner_m_ph_{}_{}.npy'.format(ph, cond))))
r_m_outer = prune(np.load(os.path.join(data_dir, 'r_values', 'r_outer_m_ph_{}_{}.npy'.format(ph, cond))))
r_gt_inner = prune(np.load(os.path.join(data_dir, 'r_values', 'r_inner_gt_ph_{}_{}.npy'.format(ph, cond))))
r_gt_outer = prune(np.load(os.path.join(data_dir, 'r_values', 'r_outer_gt_ph_{}_{}.npy'.format(ph, cond))))

# %%
r_m_inner.shape
# Out:
# (3581511,)

# %%
np.unique(np.where(np.load(os.path.join(data_dir, 'r_values', 'r_inner_m_ph_{}_{}.npy'.format(ph, cond))) > 2 )[0])
# Out:
# array([  75,   92,  843, 1189, 2348, 2726, 3823, 4811, 5549, 6490],
#       dtype=int64)

# %%
r = np.load(os.path.join(data_dir, 'r_values', 'r_inner_m_ph_{}_{}.npy'.format(ph, cond)))
np.where(np.isinf(r))
# Out:
# (array([5152], dtype=int64), array([424], dtype=int64))

# %%
colors= ['#a6cee3','#1f78b4','#b2df8a','#33a02c']
colors= ['#e66101','#fdb863','#b2abd2','#5e3c99']
colors= ['#d01c8b','#f1b6da','#b8e186','#4dac26']
colors= ['cyan', 'magenta', (0, 0.5, 0.5), (0.5, 0, 0.5)]

# %%
c = (0.5, 0.5, 0)
# Out:
# 0.4980392156862745

# %%
from matplotlib.colors import to_rgb

# %%
to_rgb('cyan')
# Out:
# (0.0, 1.0, 1.0)

# %%
np.isinf(r_m_inner).sum()
# Out:
# 1

# %%
plt.figure(figsize=(8,6))

h = plt.hist(r_gt_inner[::1], bins='fd', linewidth=1.5, histtype='step', color=colors[0])
h = plt.hist(r_gt_inner[::1], bins='fd', linewidth=0, alpha=0.2, color=colors[0])

h = plt.hist(r_gt_outer[::1], bins='fd', linewidth=1.5, linestyle='-', histtype='step', color=colors[1])
h = plt.hist(r_gt_outer[::1], bins='fd', linewidth=0, linestyle='-', alpha=0.2, color=colors[1])

h = plt.hist(r_m_inner[::1], bins='fd', linewidth=2, histtype='step', color=colors[2])
#h = plt.hist(r_m_inner[:10000], bins='fd', linewidth=0,  color=colors[0], zorder=-1)

h = plt.hist(r_m_outer[::1], bins='fd', linewidth=2, histtype='step', color=colors[3])
#h = plt.hist(r_m_outer[:10000], bins='fd', linewidth=0, color=colors[3], zorder=-1)
plt.xlim(0, 2)
plt.savefig('test.pdf')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
h
# Out:
# (array([  2.,   0.,   3.,   4.,   5.,  12.,  16.,  27.,  23.,  36.,  41.,
#          66.,  66.,  94., 117., 173., 193., 231., 247., 284., 343., 402.,
#         447., 469., 488., 490., 501., 478., 493., 455., 471., 385., 377.,
#         377., 310., 308., 242., 246., 203., 167., 129., 110.,  82.,  65.,
#          71.,  45.,  39.,  26.,  22.,  20.,  11.,  16.,  12.,  10.,   8.,
#           7.,   6.,   9.,   6.,   4.,   3.,   2.,   2.,   0.,   0.,   0.,
#           1.,   0.,   1.,   0.,   1.]),
#  array([0.99780854, 1.00774009, 1.01767165, 1.0276032 , 1.03753476,
#         1.04746631, 1.05739787, 1.06732942, 1.07726098, 1.08719253,
#         1.09712409, 1.10705564, 1.1169872 , 1.12691875, 1.1368503 ,
#         1.14678186, 1.15671341, 1.16664497, 1.17657652, 1.18650808,
#         1.19643963, 1.20637119, 1.21630274, 1.2262343 , 1.23616585,
#         1.24609741, 1.25602896, 1.26596052, 1.27589207, 1.28582363,
#         1.29575518, 1.30568673, 1.31561829, 1.32554984, 1.3354814 ,
# ...
