# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_dir = r'D:\Projects\CC_paper\figure_6_v3'

# %%
ph = 10000
cond = 'brightfield'
vals10000 = np.loadtxt(os.path.join(data_dir, 'obj_values', 'obj_vals_storm_ph_{}_{}.txt'.format(ph, cond)))

# %%
v
# Out:
# array([1.15397449, 2.15436181, 1.17014943, ..., 2.7188296 , 3.11632687,
#        1.7228914 ])

# %%
ph = 500
cond = 'brightfield'
vals10000 = np.loadtxt(os.path.join(data_dir, 'obj_values', 'obj_vals_storm_ph_{}_{}.txt'.format(ph, cond)))
v = vals10000[:, 0] / vals10000[:, 1]
cond = 'binary'
vals10000 = np.loadtxt(os.path.join(data_dir, 'obj_values', 'obj_vals_storm_ph_{}_{}.txt'.format(ph, cond)))
v1 = vals10000[:, 0] / vals10000[:, 1]

# %%
cond = 'storm_inner'
vals10000 = np.loadtxt(os.path.join(data_dir, 'obj_values', 'obj_vals_storm_ph_{}_{}.txt'.format(ph, cond)))
v2 = vals10000[:, 0] / vals10000[:, 1]

# %%
v2
# Out:
# array([9.92039179e-01, 1.00173712e+07, 9.93055383e-01, ...,
#        9.90826923e-01, 9.88276393e-01, 9.98000827e-01])

# %%
binwidth = 0.2
bins=np.arange(0, 25+ binwidth, binwidth)
bins = 10**np.arange(-1, 1.5, 0.05)
plt.figure()
h = plt.hist(v, bins=bins)
h = plt.hist(v1, bins=bins, alpha=0.5)
#h = plt.hist(v2, bins=bins, alpha=0.5)

#plt.xscale('log')
plt.gca().axvline(1, color='r')
plt.xlim(8e-1, 30)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.8, 30)

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
binwidth = 0.2
bins=np.arange(0, 50 + binwidth, binwidth)
bins_l = 10**np.arange(-1, 5.5, 0.05)

plt.figure()
h = plt.hist(v1, bins=bins, color='#333333')
ax = plt.gca()
axins = inset_axes(ax, width=2.5*1.3, height=2.5*0.9)
#h = plt.hist(v1, bins=bins, alpha=0.5)
#h = plt.hist(v2, bins=bins, alpha=0.5)
axins.hist(v1, bins=bins_l, color='#333333')
axins.set_xscale('log')
axins.axvline(1, color='r')

#plt.xscale('log')
ax.axvline(1, color='r')
plt.xlim(8e-1, 1000)
#plt.savefig('10k_storm.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.8, 1000)

# %%
ph = 1000
cond = 'storm_inner'
vals1000 = np.loadtxt(os.path.join(data_dir, 'obj_values', 'obj_diff_ph_{}_{}.txt'.format(ph, cond)))

# %%
plt.figure()
h = plt.hist(vals10000, bins='fd')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
h = plt.hist(vals1000, bins='fd')
h = plt.hist(vals10000, bins='fd', alpha =0.6)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.sum(vals10000 > (vals10000.mean() + 2*vals10000.std()))
# Out:
# 164

# %%
np.sum(vals1000 > (vals1000.mean() + 2*vals1000.std()))
# Out:
# 143

# %%
np.sum(vals10000/100 > 1e6)
# Out:
# 172
